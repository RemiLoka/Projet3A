# %%
# !pip install --upgrade wandb
# !pip install transformers[torch]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# !python3 train.py --config ./config/gpt-705M.yaml
# !python3 train.py --config ./config/llama-360M.yaml
# Out:
# 2024-01-08 15:41:57.225925: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-08 15:41:58.031432: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading data from data/babylm_10M_clean/tokenized_GPT2TokenizerFast_16000.pt
# Loading data from data/babylm_dev_clean/tokenized_GPT2TokenizerFast_16000.pt
# model parameters = 704928768
# wandb: Currently logged in as: reloka. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /home/remiloka34/BabyLlama/wandb/run-20240108_154212-i6zbzx5x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run GPT2-705M
# ...

# %%
# !python3 distill-ensemble-pretraining-baby-llama.py
# Out:
# 2024-01-11 09:19:23.705334: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-11 09:19:24.487262: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading data from data/babylm_10M_clean/tokenized_GPT2TokenizerFast_16000.pt
# Loading data from data/babylm_dev_clean/tokenized_GPT2TokenizerFast_16000.pt
# Traceback (most recent call last):
#   File "/home/remiloka34/.local/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py", line 261, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.10/dist-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# ...
